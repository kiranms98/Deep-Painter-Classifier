# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#preliminary test to ensure GPU is working

import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
#preliminary test to check CPU Vs GPU time

import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 3.538984092003375
# GPU (s):
# 0.036736055997607764
# GPU speedup over CPU: 96x

# %%
import numpy as np
import tensorflow as tf
import datetime
from tensorflow.keras.layers import Dense, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, Conv2DTranspose, UpSampling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import TensorBoard
#import tensorflow_addons as tfa
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
from tqdm import tqdm, tqdm_notebook

import random
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from numpy.random import seed
seed(1)
tf.random.set_seed(1)

# %%
artists = pd.read_csv(r'art5.csv')
artists.shape
# Out:
# (5, 8)

# %%
#specify the directory containing the image-training set

images_dir = r'train'
artists_dirs = os.listdir(images_dir)
artists_top_name = artists['name'].str.replace(' ', '_').values

# %%
n = 5
fig, axes = plt.subplots(1, n, figsize=(20,10))

for i in range(n):
    random_artist = random.choice(artists_top_name)
    random_image = random.choice(os.listdir(os.path.join(images_dir, random_artist)))
    random_image_file = os.path.join(images_dir, random_artist, random_image)
    image = plt.imread(random_image_file)
    
    axes[i].imshow(image)
    axes[i].set_title("Artist: " + random_artist.replace('_', ' '))
    axes[i].axis('off')

plt.show()

# %%
batch_size = 1
train_input_shape = (256, 256,3)
n_classes = artists.shape[0]

# %%
img_width, img_height = 256, 256

# %%
#this section implements the data generation and data augmentation

train_datagen = ImageDataGenerator(validation_split=0.2,
                                   rescale=1./255.,
                                   rotation_range=45,
                                   width_shift_range=0.5,
                                   height_shift_range=0.5,
                                   shear_range=5,
                                   zoom_range=0.7,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                  )

train_generator = train_datagen.flow_from_directory(directory=images_dir,
                                                    class_mode='categorical',
                                                    target_size=(img_width, img_height),
                                                    color_mode="rgb",
                                                    batch_size=120,
                                                    subset="training",
                                                    shuffle=True,
                                                    classes=artists_top_name.tolist()
                                                   )

valid_generator = train_datagen.flow_from_directory(directory=images_dir,
                                                    class_mode='categorical',
                                                    target_size=(img_width, img_height),
                                                    color_mode="rgb",
                                                    batch_size=30,
                                                    subset="validation",
                                                    shuffle=True,
                                                    classes=artists_top_name.tolist()
                                                   )

STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size
print("Total number of batches =", STEP_SIZE_TRAIN, "and", STEP_SIZE_VALID)
# Out:
# Found 1314 images belonging to 5 classes.
# Found 326 images belonging to 5 classes.
# Total number of batches = 10 and 10

# %%
X_train, y_train = train_generator.next()
X_test, y_test = valid_generator.next()

# %%
y_train.shape
# Out:
# (120, 5)

# %%
pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in ./envTF24/lib/python3.6/site-packages (0.14.0)
# Requirement already satisfied: typeguard>=2.7 in ./envTF24/lib/python3.6/site-packages (from tensorflow_addons) (2.13.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
#this section contains the model as described in the author's paper

######start of the encoder part######

input_img = keras.Input(shape=(img_width, img_height, 3))

x = layers.Conv2D(100, (5, 5), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(200, (5, 5), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)

#######end of the encoder part#######

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

######start of the decoder part######

x = layers.UpSampling2D((2, 2))(encoded)
x = layers.Conv2DTranspose(200, (5, 5), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2DTranspose(100, (5, 5), activation='relu', padding='same')(x)
decoded = layers.Conv2DTranspose(3, (5, 5), activation='sigmoid', padding='same')(x)

autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='mean_squared_error',metrics=['accuracy'])

# %%
n_epoch = 200
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=5, 
                              verbose=1, mode='auto')

# %%
history = autoencoder.fit(X_train,X_train,steps_per_epoch=STEP_SIZE_TRAIN,
          epochs=n_epoch,
          validation_data=(X_test,X_test),
          verbose=1,
          callbacks=[reduce_lr],
          batch_size=10,
          )
# Out:
# Epoch 1/200
# 10/10 [==============================] - 14s 522ms/step - loss: 0.1006 - accuracy: 0.4950 - val_loss: 0.0820 - val_accuracy: 0.6807
# Epoch 2/200
# 10/10 [==============================] - 5s 505ms/step - loss: 0.0758 - accuracy: 0.6521 - val_loss: 0.0461 - val_accuracy: 0.7140
# Epoch 3/200
# 10/10 [==============================] - 5s 498ms/step - loss: 0.0494 - accuracy: 0.6668 - val_loss: 0.0412 - val_accuracy: 0.4513
# Epoch 4/200
# 10/10 [==============================] - 5s 491ms/step - loss: 0.0279 - accuracy: 0.5069 - val_loss: 0.0158 - val_accuracy: 0.5901
# Epoch 5/200
# 10/10 [==============================] - 5s 500ms/step - loss: 0.0166 - accuracy: 0.5540 - val_loss: 0.0164 - val_accuracy: 0.6846
# Epoch 6/200
# 10/10 [==============================] - 5s 484ms/step - loss: 0.
200
# 10/10 [==============================] - 5s 485ms/step - loss: 0.0013 - accuracy: 0.8686 - val_loss: 0.0021 - val_accuracy: 0.8690
# Epoch 197/200
# 10/10 [==============================] - 5s 485ms/step - loss: 0.0019 - accuracy: 0.8856 - val_loss: 0.0021 - val_accuracy: 0.8689
# Epoch 198/200
# 10/10 [==============================] - 5s 484ms/step - loss: 0.0016 - accuracy: 0.8911 - val_loss: 0.0021 - val_accuracy: 0.8664
#
# Epoch 00198: ReduceLROnPlateau reducing learning rate to 5.233476658759173e-05.
# Epoch 199/200
# 10/10 [==============================] - 5s 485ms/step - loss: 0.0015 - accuracy: 0.8666 - val_loss: 0.0021 - val_accuracy: 0.8710
# Epoch 200/200
# 10/10 [==============================] - 5s 484ms/step - loss: 0.0017 - accuracy: 0.9040 - val_loss: 0.0021 - val_accuracy: 0.8692

# %%
from matplotlib import pyplot
pyplot.plot(history.history['accuracy'], label='train')
pyplot.plot(history.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %%
# In this section, we construct the artist-classifier CNN. The weights of the autoencoder are saved and loaded into a new model
# called 'model3'. For model3, only the first 5 layer of the autoencoder have been copied - Input, Conv2D, MaxPooling2D, Conv2D,
# and MaxPooling2D. This has been implemented by the function autoencoder.layers[:,-5]. Only the weights for these layers have
# been loaded onto model3. The output of model3 is fed into 2 fully-connected layers (as described in the original paper).
# A Flatten() layer is added just before the fully connected 5-neuron layer with the softmax classifier. Only these Dense()
# layers are trained. Using the for-loop, the encoder-layers have been rendered non-trainable


autoencoder.save_weights('autoencoder.h5')
model3 = tf.keras.models.Sequential(autoencoder.layers[:-5])
model3.load_weights('autoencoder.h5', by_name=True)

x = layers.Dense(400, activation='relu')(model3.output)
x = layers.Dense(200, activation='relu')(x)
x = layers.Flatten()(x)
final = layers.Dense(5, activation='softmax')(x)

for layer in model3.layers[:4]:
    layer.trainable=False

# %%
identifier = keras.Model(model3.input,final)
opt = keras.optimizers.Adam(learning_rate=0.0001)
identifier.compile(optimizer=opt, loss='categorical_crossentropy',metrics=['accuracy'])

# %%
identifier.summary()

# %%
history3 = identifier.fit(train_generator, steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator, validation_steps=STEP_SIZE_VALID,
                              epochs=100,
                              shuffle=True,
                              verbose=1,
                              callbacks=[reduce_lr]
                             )
# Out:
# Epoch 1/100
# 10/10 [==============================] - 51s 5s/step - loss: 1.4973 - accuracy: 0.3149 - val_loss: 1.3532 - val_accuracy: 0.4200
# Epoch 2/100
# 10/10 [==============================] - 47s 5s/step - loss: 1.2591 - accuracy: 0.4397 - val_loss: 1.3257 - val_accuracy: 0.4933
# Epoch 3/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.1796 - accuracy: 0.4941 - val_loss: 1.1945 - val_accuracy: 0.5067
# Epoch 4/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.1105 - accuracy: 0.5310 - val_loss: 1.2963 - val_accuracy: 0.4600
# Epoch 5/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.1055 - accuracy: 0.5402 - val_loss: 1.2363 - val_accuracy: 0.5100
# Epoch 6/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.1121 - accuracy: 0.5335 - val_loss: 1.1994 - val_accuracy: 0.5467
# Epoch 7/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.0525 - accuracy: 0.5620 - val_loss: 1.1418 - val_accuracy: 0.5433
# Epoch 8/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.0591 - accuracy: 0.5544 - val_loss: 1.2125 - val_accuracy: 0.5433
# Epoch 9/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.0535 - accuracy: 0.5729 - val_loss: 1.0986 - val_accuracy: 0.5600
# Epoch 10/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.0438 - accuracy: 0.5729 - val_loss: 1.1453 - val_accuracy: 0.5500
# Epoch 11/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.0336 - accuracy: 0.5717 - val_loss: 1.1130 - val_accuracy: 0.5800
# Epoch 12/100
# 10/10 [==============================] - 47s 5s/step - loss: 1.0294 - accuracy: 0.5879 - val_loss: 1.1208 - val_accuracy: 0.5733
# Epoch 13/100
# 10/10 [==============================] - 47s 5s/step - loss: 1.0027 - accuracy: 0.5879 - val_loss: 1.0905 - val_accuracy: 0.5833
# Epoch 14/100
# 10/10 [==============================] - 47s 5s/step - loss: 1.0122 - accuracy: 0.5846 - val_loss: 1.0610 - val_accuracy: 0.5933
# Epoch 15/100
# 10/10 [==============================] - 46s 5s/step - loss: 1.0139 - accuracy: 0.5796 - val_loss: 1.0987 - val_accuracy: 0.5667
# Epoch 16/100
# 10/10 [==============================] - 47s 5s/step - loss: 1.0222 - accuracy: 0.5729 - val_loss: 1.0924 - val_accuracy: 0.5967
# Epoch 17/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9929 - accuracy: 0.5963 - val_loss: 1.0802 - val_accuracy: 0.5733
# Epoch 18/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9793 - accuracy: 0.5946 - val_loss: 1.1003 - val_accuracy: 0.5600
# Epoch 19/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9894 - accuracy: 0.6156 - val_loss: 1.1122 - val_accuracy: 0.6000
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 8.999999772640876e-05.
# Epoch 20/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9603 - accuracy: 0.6131 - val_loss: 1.0794 - val_accuracy: 0.6167
# Epoch 21/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9746 - accuracy: 0.6064 - val_loss: 1.1284 - val_accuracy: 0.5733
# Epoch 22/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9604 - accuracy: 0.6013 - val_loss: 1.0777 - val_accuracy: 0.5900
# Epoch 23/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9593 - accuracy: 0.6223 - val_loss: 1.1018 - val_accuracy: 0.6067
# Epoch 24/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.9437 - accuracy: 0.6265 - val_loss: 1.0803 - val_accuracy: 0.5867
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 8.100000122794882e-05.
# Epoch 25/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.9527 - accuracy: 0.6131 - val_loss: 1.0180 - val_accuracy: 0.6133
# Epoch 26/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.9304 - accuracy: 0.6131 - val_loss: 1.0150 - val_accuracy: 0.6267
# Epoch 27/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9355 - accuracy: 0.6206 - val_loss: 1.1203 - val_accuracy: 0.5833
# Epoch 28/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.9497 - accuracy: 0.6114 - val_loss: 1.0966 - val_accuracy: 0.5933
# Epoch 29/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9332 - accuracy: 0.6298 - val_loss: 1.0403 - val_accuracy: 0.6033
# Epoch 30/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9292 - accuracy: 0.6147 - val_loss: 1.0143 - val_accuracy: 0.6000
# Epoch 31/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9283 - accuracy: 0.6323 - val_loss: 1.1168 - val_accuracy: 0.5800
# Epoch 32/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9307 - accuracy: 0.6265 - val_loss: 1.0519 - val_accuracy: 0.5800
# Epoch 33/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8925 - accuracy: 0.6466 - val_loss: 1.0793 - val_accuracy: 0.6100
# Epoch 34/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8893 - accuracy: 0.6482 - val_loss: 0.9928 - val_accuracy: 0.6067
# Epoch 35/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.9292 - accuracy: 0.6441 - val_loss: 1.0745 - val_accuracy: 0.6133
# Epoch 36/100
# 10/10 [==============================] - 48s 5s/step - loss: 0.9177 - accuracy: 0.6315 - val_loss: 1.0329 - val_accuracy: 0.6300
# Epoch 37/100
# 10/10 [==============================] - 48s 5s/step - loss: 0.9226 - accuracy: 0.6332 - val_loss: 1.0246 - val_accuracy: 0.6233
# Epoch 38/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.9195 - accuracy: 0.6315 - val_loss: 1.0361 - val_accuracy: 0.6100
# Epoch 39/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.8877 - accuracy: 0.6407 - val_loss: 1.1245 - val_accuracy: 0.5500
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 7.289999848580919e-05.
# Epoch 40/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8842 - accuracy: 0.6365 - val_loss: 1.0751 - val_accuracy: 0.5767
# Epoch 41/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8998 - accuracy: 0.6265 - val_loss: 1.0330 - val_accuracy: 0.5967
# Epoch 42/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.9044 - accuracy: 0.6273 - val_loss: 1.0228 - val_accuracy: 0.6133
# Epoch 43/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.
100
# 10/10 [==============================] - 47s 5s/step - loss: 0.8471 - accuracy: 0.6667 - val_loss: 0.9485 - val_accuracy: 0.6400
# Epoch 74/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8404 - accuracy: 0.6700 - val_loss: 1.0402 - val_accuracy: 0.5967
# Epoch 75/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.8568 - accuracy: 0.6600 - val_loss: 0.9954 - val_accuracy: 0.6067
# Epoch 76/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8482 - accuracy: 0.6734 - val_loss: 0.9930 - val_accuracy: 0.6200
# Epoch 77/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8389 - accuracy: 0.6600 - val_loss: 0.9715 - val_accuracy: 0.6133
# Epoch 78/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.8524 - accuracy: 0.6642 - val_loss: 1.0396 - val_accuracy: 0.6233
#
# Epoch 00078: ReduceLROnPlateau reducing learning rate to 3.8742047036066654e-05.
# Epoch 79/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8326 - accuracy: 0.6734 - val_loss: 1.0601 - val_accuracy: 0.6100
# Epoch 80/100
# 10/10 [==============================] - 45s 5s/step - loss: 0.8518 - accuracy: 0.6575 - val_loss: 1.0083 - val_accuracy: 0.6200
# Epoch 81/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8465 - accuracy: 0.6608 - val_loss: 0.9562 - val_accuracy: 0.6400
# Epoch 82/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8664 - accuracy: 0.6608 - val_loss: 0.9340 - val_accuracy: 0.6233
# Epoch 83/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.8448 - accuracy: 0.6792 - val_loss: 0.9866 - val_accuracy: 0.6367
# Epoch 84/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.8295 - accuracy: 0.6767 - val_loss: 1.0304 - val_accuracy: 0.6300
# Epoch 85/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8476 - accuracy: 0.6700 - val_loss: 0.9543 - val_accuracy: 0.6467
# Epoch 86/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8418 - accuracy: 0.6717 - val_loss: 1.0318 - val_accuracy: 0.6067
# Epoch 87/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8879 - accuracy: 0.6516 - val_loss: 0.9763 - val_accuracy: 0.6333
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 3.4867842987296176e-05.
# Epoch 88/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8159 - accuracy: 0.6801 - val_loss: 0.9722 - val_accuracy: 0.6233
# Epoch 89/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8391 - accuracy: 0.6667 - val_loss: 0.9752 - val_accuracy: 0.6200
# Epoch 90/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8391 - accuracy: 0.6683 - val_loss: 1.0083 - val_accuracy: 0.6233
# Epoch 91/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8405 - accuracy: 0.6600 - val_loss: 0.9794 - val_accuracy: 0.6300
# Epoch 92/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8344 - accuracy: 0.6759 - val_loss: 0.9556 - val_accuracy: 0.6233
#
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 3.138105967082083e-05.
# Epoch 93/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8532 - accuracy: 0.6558 - val_loss: 1.0333 - val_accuracy: 0.5967
# Epoch 94/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8438 - accuracy: 0.6642 - val_loss: 1.0027 - val_accuracy: 0.6433
# Epoch 95/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.8515 - accuracy: 0.6650 - val_loss: 0.9328 - val_accuracy: 0.6633
# Epoch 96/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.8414 - accuracy: 0.6734 - val_loss: 1.0198 - val_accuracy: 0.6233
# Epoch 97/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8455 - accuracy: 0.6658 - val_loss: 1.0453 - val_accuracy: 0.5867
# Epoch 98/100
# 10/10 [==============================] - 48s 5s/step - loss: 0.8295 - accuracy: 0.6683 - val_loss: 0.9645 - val_accuracy: 0.6500
# Epoch 99/100
# 10/10 [==============================] - 47s 5s/step - loss: 0.8381 - accuracy: 0.6683 - val_loss: 0.9216 - val_accuracy: 0.6567
# Epoch 100/100
# 10/10 [==============================] - 46s 5s/step - loss: 0.8463 - accuracy: 0.6784 - val_loss: 1.0186 - val_accuracy: 0.6267

# %%
from matplotlib import pyplot
pyplot.plot(history3.history['accuracy'], label='train')
pyplot.plot(history3.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()
