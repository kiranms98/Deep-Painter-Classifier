# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#preliminary test to ensure GPU is working

import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
#preliminary test to check CPU Vs GPU time

import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 3.5999155799945584
# GPU (s):
# 0.039510276008513756
# GPU speedup over CPU: 91x

# %%
import numpy as np
import tensorflow as tf
import datetime
from tensorflow.keras.layers import Dense, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, Conv2DTranspose, UpSampling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.callbacks import TensorBoard
#import tensorflow_addons as tfa
import pandas as pd
import matplotlib.pyplot as plt
import json
import os
from tqdm import tqdm, tqdm_notebook

import random
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from numpy.random import seed
seed(1)
tf.random.set_seed(1)

# %%
artists = pd.read_csv(r'art5.csv')
artists.shape
# Out:
# (5, 8)

# %%
#specify the directory containing the image-training set

images_dir = r'train'
artists_dirs = os.listdir(images_dir)
artists_top_name = artists['name'].str.replace(' ', '_').values

# %%
n = 5
fig, axes = plt.subplots(1, n, figsize=(20,10))

for i in range(n):
    random_artist = random.choice(artists_top_name)
    random_image = random.choice(os.listdir(os.path.join(images_dir, random_artist)))
    random_image_file = os.path.join(images_dir, random_artist, random_image)
    image = plt.imread(random_image_file)
    
    axes[i].imshow(image)
    axes[i].set_title("Artist: " + random_artist.replace('_', ' '))
    axes[i].axis('off')

plt.show()

# %%
batch_size = 1
train_input_shape = (256, 256,3)
n_classes = artists.shape[0]

# %%
img_width, img_height = 256, 256

# %%
#this section implements the data generation and data augmentation

train_datagen = ImageDataGenerator(validation_split=0.2,
                                   rescale=1./255.,
                                   rotation_range=45,
                                   width_shift_range=0.5,
                                   height_shift_range=0.5,
                                   shear_range=5,
                                   zoom_range=0.7,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                  )

train_generator = train_datagen.flow_from_directory(directory=images_dir,
                                                    class_mode='categorical',
                                                    target_size=(img_width, img_height),
                                                    color_mode="rgb",
                                                    batch_size=120,
                                                    subset="training",
                                                    shuffle=True,
                                                    classes=artists_top_name.tolist()
                                                   )

valid_generator = train_datagen.flow_from_directory(directory=images_dir,
                                                    class_mode='categorical',
                                                    target_size=(img_width, img_height),
                                                    color_mode="rgb",
                                                    batch_size=30,
                                                    subset="validation",
                                                    shuffle=True,
                                                    classes=artists_top_name.tolist()
                                                   )

STEP_SIZE_TRAIN = train_generator.n//train_generator.batch_size
STEP_SIZE_VALID = valid_generator.n//valid_generator.batch_size
print("Total number of batches =", STEP_SIZE_TRAIN, "and", STEP_SIZE_VALID)
# Out:
# Found 1314 images belonging to 5 classes.
# Found 326 images belonging to 5 classes.
# Total number of batches = 10 and 10

# %%
X_train, y_train = train_generator.next()
X_test, y_test = valid_generator.next()

# %%
y_train.shape
# Out:
# (120, 5)

# %%
pip install tensorflow_addons
# Out:
# Requirement already satisfied: tensorflow_addons in ./envTF24/lib/python3.6/site-packages (0.14.0)
# Requirement already satisfied: typeguard>=2.7 in ./envTF24/lib/python3.6/site-packages (from tensorflow_addons) (2.13.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow import keras
from tensorflow.keras import layers

# %%
n_epoch = 200
# early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1, 
#                            mode='auto', restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=5, 
                              verbose=1, mode='auto')

# %% [markdown]
# ## VGG16 model:

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
vgg = VGG16(input_shape=[256,256]+[3],weights='imagenet',include_top=False)
for layer in vgg.layers:
    layer.trainable = False

x = Flatten()(vgg.output)
prediction = Dense(5,activation='softmax')(x)
model1 = Model(inputs=vgg.input,outputs=prediction)

# %%
model1.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history4 = model1.fit(train_generator, steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator, validation_steps=STEP_SIZE_VALID,
                              epochs=50,
                              shuffle=True,
                              verbose=1,
                              callbacks=[reduce_lr]
                             )
# Out:
# Epoch 1/50
# 10/10 [==============================] - 88s 7s/step - loss: 2.5948 - accuracy: 0.2379 - val_loss: 1.5540 - val_accuracy: 0.4200
# Epoch 2/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.4712 - accuracy: 0.4388 - val_loss: 1.2068 - val_accuracy: 0.5533
# Epoch 3/50
# 10/10 [==============================] - 48s 5s/step - loss: 1.1201 - accuracy: 0.5733 - val_loss: 1.1238 - val_accuracy: 0.5833
# Epoch 4/50
# 10/10 [==============================] - 48s 5s/step - loss: 1.0751 - accuracy: 0.5984 - val_loss: 1.0580 - val_accuracy: 0.6233
# Epoch 5/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.9574 - accuracy: 0.6467 - val_loss: 0.9892 - val_accuracy: 0.5867
# Epoch 6/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.9382 - accuracy: 0.6222 - val_loss: 1.0346 - val_accuracy: 0.6100
# Epoch 7/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.9297 - accuracy: 0.6305 - val_loss: 0.9956 - val_accuracy: 0.6133
# Epoch 8/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.8545 - accuracy: 0.6739 - val_loss: 0.9399 - val_accuracy: 0.6533
# Epoch 9/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.8442 - accuracy: 0.6951 - val_loss: 0.9537 - val_accuracy: 0.6500
# Epoch 10/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.9157 - accuracy: 0.6372 - val_loss: 1.1775 - val_accuracy: 0.5767
# Epoch 11/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.9195 - accuracy: 0.6466 - val_loss: 1.1003 - val_accuracy: 0.5967
# Epoch 12/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.8555 - accuracy: 0.6857 - val_loss: 0.9876 - val_accuracy: 0.6533
# Epoch 13/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.8757 - accuracy: 0.6680 - val_loss: 1.0007 - val_accuracy: 0.6300
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 14/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.8799 - accuracy: 0.6680 - val_loss: 1.0744 - val_accuracy: 0.6100
# Epoch 15/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.9027 - accuracy: 0.6441 - val_loss: 0.9240 - val_accuracy: 0.6400
# Epoch 16/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.8663 - accuracy: 0.6649 - val_loss: 0.9659 - val_accuracy: 0.6467
# Epoch 17/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.8390 - accuracy: 0.6806 - val_loss: 0.9989 - val_accuracy: 0.6300
# Epoch 18/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7962 - accuracy: 0.6996 - val_loss: 1.1158 - val_accuracy: 0.5733
# Epoch 19/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.8727 - accuracy: 0.6686 - val_loss: 1.0208 - val_accuracy: 0.6067
# Epoch 20/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7876 - accuracy: 0.6925 - val_loss: 0.8992 - val_accuracy: 0.6567
# Epoch 21/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7647 - accuracy: 0.7073 - val_loss: 0.9863 - val_accuracy: 0.6567
# Epoch 22/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.8447 - accuracy: 0.6801 - val_loss: 0.9833 - val_accuracy: 0.6400
# Epoch 23/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.8459 - accuracy: 0.6741 - val_loss: 0.9279 - val_accuracy: 0.6600
# Epoch 24/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.8218 - accuracy: 0.6846 - val_loss: 0.9457 - val_accuracy: 0.6700
# Epoch 25/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.7592 - accuracy: 0.7134 - val_loss: 0.8443 - val_accuracy: 0.6700
# Epoch 26/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7508 - accuracy: 0.7133 - val_loss: 0.9032 - val_accuracy: 0.6700
# Epoch 27/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.7456 - accuracy: 0.7081 - val_loss: 0.9203 - val_accuracy: 0.6800
# Epoch 28/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.8067 - accuracy: 0.6911 - val_loss: 0.8565 - val_accuracy: 0.6767
# Epoch 29/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7586 - accuracy: 0.6968 - val_loss: 0.8821 - val_accuracy: 0.6833
# Epoch 30/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7074 - accuracy: 0.7269 - val_loss: 0.9389 - val_accuracy: 0.6500
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 31/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7520 - accuracy: 0.7259 - val_loss: 0.8613 - val_accuracy: 0.6500
# Epoch 32/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.8093 - accuracy: 0.7057 - val_loss: 0.9289 - val_accuracy: 0.6667
# Epoch 33/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.7587 - accuracy: 0.7104 - val_loss: 0.9205 - val_accuracy: 0.6533
# Epoch 34/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7443 - accuracy: 0.7164 - val_loss: 0.8287 - val_accuracy: 0.6867
# Epoch 35/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.6864 - accuracy: 0.7529 - val_loss: 0.8997 - val_accuracy: 0.7000
# Epoch 36/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.7033 - accuracy: 0.7215 - val_loss: 0.8576 - val_accuracy: 0.6867
# Epoch 37/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7579 - accuracy: 0.7106 - val_loss: 0.9666 - val_accuracy: 0.6633
# Epoch 38/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.7581 - accuracy: 0.7059 - val_loss: 0.9195 - val_accuracy: 0.6667
# Epoch 39/50
# 10/10 [==============================] - 48s 5s/step - loss: 0.7497 - accuracy: 0.7046 - val_loss: 0.9011 - val_accuracy: 0.6700
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 40/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7405 - accuracy: 0.7056 - val_loss: 0.9788 - val_accuracy: 0.6500
# Epoch 41/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7300 - accuracy: 0.7327 - val_loss: 0.9664 - val_accuracy: 0.6100
# Epoch 42/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7385 - accuracy: 0.7144 - val_loss: 1.0233 - val_accuracy: 0.6433
# Epoch 43/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7417 - accuracy: 0.7060 - val_loss: 0.9918 - val_accuracy: 0.6533
# Epoch 44/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.8002 - accuracy: 0.6814 - val_loss: 0.9089 - val_accuracy: 0.6733
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 45/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.7205 - accuracy: 0.7483 - val_loss: 0.9273 - val_accuracy: 0.6767
# Epoch 46/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7195 - accuracy: 0.7290 - val_loss: 0.9023 - val_accuracy: 0.6767
# Epoch 47/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.7025 - accuracy: 0.7273 - val_loss: 0.8254 - val_accuracy: 0.7033
# Epoch 48/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7162 - accuracy: 0.7176 - val_loss: 0.9881 - val_accuracy: 0.6500
# Epoch 49/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.6972 - accuracy: 0.7405 - val_loss: 0.8513 - val_accuracy: 0.6633
# Epoch 50/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.7235 - accuracy: 0.7197 - val_loss: 0.8853 - val_accuracy: 0.6667

# %%
from matplotlib import pyplot
pyplot.plot(history4.history['accuracy'], label='train')
pyplot.plot(history4.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## Xception model:

# %%
base_model=tf.keras.applications.Xception(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(256,256,3),
    pooling=None,
    classes=1000,
    classifier_activation="softmax",
)

for layer in base_model.layers:
    layer.trainable = False

x = Flatten()(base_model.output)
prediction = Dense(5,activation='softmax')(x)
model2 = Model(inputs=base_model.input,outputs=prediction)
#model2.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step

# %%
model2.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history5 = model2.fit(train_generator, steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator, validation_steps=STEP_SIZE_VALID,
                              epochs=50,
                              shuffle=True,
                              verbose=1,
                              callbacks=[reduce_lr]
                             )
# Out:
# Epoch 1/50
# 10/10 [==============================] - 54s 5s/step - loss: 10.3805 - accuracy: 0.2460 - val_loss: 6.7304 - val_accuracy: 0.5167
# Epoch 2/50
# 10/10 [==============================] - 47s 5s/step - loss: 6.1500 - accuracy: 0.4668 - val_loss: 4.4963 - val_accuracy: 0.5467
# Epoch 3/50
# 10/10 [==============================] - 47s 5s/step - loss: 3.6915 - accuracy: 0.6054 - val_loss: 3.1007 - val_accuracy: 0.6000
# Epoch 4/50
# 10/10 [==============================] - 46s 5s/step - loss: 2.6382 - accuracy: 0.6451 - val_loss: 2.4200 - val_accuracy: 0.6167
# Epoch 5/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.9002 - accuracy: 0.6607 - val_loss: 2.0260 - val_accuracy: 0.6667
# Epoch 6/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.7566 - accuracy: 0.6733 - val_loss: 2.3551 - val_accuracy: 0.6133
# Epoch 7/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.6275 - accuracy: 0.6740 - val_loss: 1.9913 - val_accuracy: 0.6133
# Epoch 8/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.5319 - accuracy: 0.7128 - val_loss: 1.9555 - val_accuracy: 0.6067
# Epoch 9/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.5107 - accuracy: 0.6858 - val_loss: 1.8863 - val_accuracy: 0.6067
# Epoch 10/50
# 10/10 [==============================] - 48s 5s/step - loss: 1.6577 - accuracy: 0.6563 - val_loss: 1.9062 - val_accuracy: 0.6067
# Epoch 11/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.4468 - accuracy: 0.6853 - val_loss: 2.0974 - val_accuracy: 0.6267
# Epoch 12/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.5220 - accuracy: 0.6784 - val_loss: 2.6475 - val_accuracy: 0.5567
# Epoch 13/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.6167 - accuracy: 0.6822 - val_loss: 1.8132 - val_accuracy: 0.6467
# Epoch 14/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.4453 - accuracy: 0.7022 - val_loss: 2.0860 - val_accuracy: 0.6033
# Epoch 15/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.6005 - accuracy: 0.6502 - val_loss: 2.0472 - val_accuracy: 0.6067
# Epoch 16/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.2798 - accuracy: 0.7149 - val_loss: 1.9450 - val_accuracy: 0.6600
# Epoch 17/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.4058 - accuracy: 0.7099 - val_loss: 1.8611 - val_accuracy: 0.6433
# Epoch 18/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.5847 - accuracy: 0.6963 - val_loss: 2.1972 - val_accuracy: 0.6400
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 19/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.6732 - accuracy: 0.6740 - val_loss: 2.2141 - val_accuracy: 0.6233
# Epoch 20/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.4941 - accuracy: 0.6844 - val_loss: 1.7775 - val_accuracy: 0.6567
# Epoch 21/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.2811 - accuracy: 0.6955 - val_loss: 1.9157 - val_accuracy: 0.6833
# Epoch 22/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.5042 - accuracy: 0.7108 - val_loss: 2.1580 - val_accuracy: 0.6233
# Epoch 23/50
# 10/10 [==============================] - 48s 5s/step - loss: 1.3633 - accuracy: 0.7307 - val_loss: 1.8497 - val_accuracy: 0.6233
# Epoch 24/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.4670 - accuracy: 0.6943 - val_loss: 1.7366 - val_accuracy: 0.6367
# Epoch 25/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.4522 - accuracy: 0.6871 - val_loss: 2.3364 - val_accuracy: 0.6167
# Epoch 26/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.3263 - accuracy: 0.7135 - val_loss: 2.1175 - val_accuracy: 0.6267
# Epoch 27/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3423 - accuracy: 0.7187 - val_loss: 1.7823 - val_accuracy: 0.6833
# Epoch 28/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.2959 - accuracy: 0.7137 - val_loss: 1.9930 - val_accuracy: 0.6500
# Epoch 29/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.3288 - accuracy: 0.7266 - val_loss: 1.7496 - val_accuracy: 0.7000
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 30/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.5473 - accuracy: 0.6992 - val_loss: 1.6567 - val_accuracy: 0.6900
# Epoch 31/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.0963 - accuracy: 0.7380 - val_loss: 1.5914 - val_accuracy: 0.6833
# Epoch 32/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.1614 - accuracy: 0.7268 - val_loss: 1.7018 - val_accuracy: 0.6867
# Epoch 33/50
# 10/10 [==============================] - 48s 5s/step - loss: 1.2113 - accuracy: 0.7438 - val_loss: 1.5414 - val_accuracy: 0.7067
# Epoch 34/50
# 10/10 [==============================] - 48s 5s/step - loss: 1.1707 - accuracy: 0.7624 - val_loss: 1.9999 - val_accuracy: 0.6400
# Epoch 35/50
# 10/10 [==============================] - 48s 5s/step - loss: 1.2175 - accuracy: 0.7313 - val_loss: 1.6430 - val_accuracy: 0.7000
# Epoch 36/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.1824 - accuracy: 0.7359 - val_loss: 1.5364 - val_accuracy: 0.6700
# Epoch 37/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.0197 - accuracy: 0.7199 - val_loss: 1.5754 - val_accuracy: 0.6833
# Epoch 38/50
# 10/10 [==============================] - 47s 5s/step - loss: 0.9802 - accuracy: 0.7601 - val_loss: 1.4806 - val_accuracy: 0.6600
# Epoch 39/50
# 10/10 [==============================] - 46s 5s/step - loss: 0.9916 - accuracy: 0.7505 - val_loss: 1.5000 - val_accuracy: 0.7233
# Epoch 40/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.1098 - accuracy: 0.7473 - val_loss: 1.5642 - val_accuracy: 0.7100
# Epoch 41/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.1941 - accuracy: 0.7270 - val_loss: 1.6094 - val_accuracy: 0.7100
# Epoch 42/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.1617 - accuracy: 0.7313 - val_loss: 1.6835 - val_accuracy: 0.6567
# Epoch 43/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.2996 - accuracy: 0.7032 - val_loss: 1.3838 - val_accuracy: 0.7033
# Epoch 44/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.0094 - accuracy: 0.7562 - val_loss: 1.8344 - val_accuracy: 0.6433
# Epoch 45/50
# 10/10 [==============================] - 48s 5s/step - loss: 1.2262 - accuracy: 0.7359 - val_loss: 1.7057 - val_accuracy: 0.6667
# Epoch 46/50
# 10/10 [==============================] - 48s 5s/step - loss: 1.1159 - accuracy: 0.7368 - val_loss: 1.6650 - val_accuracy: 0.6700
# Epoch 47/50
# 10/10 [==============================] - 48s 5s/step - loss: 1.1206 - accuracy: 0.7201 - val_loss: 2.0143 - val_accuracy: 0.6233
# Epoch 48/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.2978 - accuracy: 0.7256 - val_loss: 1.6269 - val_accuracy: 0.6700
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 49/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.1845 - accuracy: 0.7444 - val_loss: 1.8118 - val_accuracy: 0.6700
# Epoch 50/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.1735 - accuracy: 0.7477 - val_loss: 2.0241 - val_accuracy: 0.6600

# %%
pyplot.plot(history5.history['accuracy'], label='train')
pyplot.plot(history5.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## MobileNet model:

# %%
base_model=tf.keras.applications.MobileNet(
    input_shape=(256,256,3),
    alpha=1.0,
    depth_multiplier=1,
    dropout=0.001,
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    pooling=None,
    classes=1000,
    classifier_activation="softmax"
)

for layer in base_model.layers:
    layer.trainable = False

x = Flatten()(base_model.output)
prediction = Dense(5,activation='softmax')(x)
model3 = Model(inputs=base_model.input,outputs=prediction)
#model3.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model3.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history6 = model3.fit(train_generator, steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator, validation_steps=STEP_SIZE_VALID,
                              epochs=50,
                              shuffle=True,
                              verbose=1,
                              callbacks=[reduce_lr]
                             )
# Out:
# Epoch 1/50
# 10/10 [==============================] - 49s 5s/step - loss: 18.0379 - accuracy: 0.2242 - val_loss: 19.1613 - val_accuracy: 0.4000
# Epoch 2/50
# 10/10 [==============================] - 45s 5s/step - loss: 11.6406 - accuracy: 0.4850 - val_loss: 4.2659 - val_accuracy: 0.6467
# Epoch 3/50
# 10/10 [==============================] - 45s 5s/step - loss: 4.5551 - accuracy: 0.6227 - val_loss: 3.6407 - val_accuracy: 0.6267
# Epoch 4/50
# 10/10 [==============================] - 45s 5s/step - loss: 3.3327 - accuracy: 0.6869 - val_loss: 3.0205 - val_accuracy: 0.6900
# Epoch 5/50
# 10/10 [==============================] - 44s 5s/step - loss: 2.8601 - accuracy: 0.6711 - val_loss: 2.5424 - val_accuracy: 0.6967
# Epoch 6/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.9460 - accuracy: 0.7405 - val_loss: 2.9127 - val_accuracy: 0.6567
# Epoch 7/50
# 10/10 [==============================] - 46s 5s/step - loss: 2.0858 - accuracy: 0.7025 - val_loss: 2.1954 - val_accuracy: 0.6933
# Epoch 8/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.7056 - accuracy: 0.7243 - val_loss: 2.2722 - val_accuracy: 0.6833
# Epoch 9/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.6816 - accuracy: 0.7277 - val_loss: 1.9814 - val_accuracy: 0.7200
# Epoch 10/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.6920 - accuracy: 0.7367 - val_loss: 1.7905 - val_accuracy: 0.6933
# Epoch 11/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.8646 - accuracy: 0.7157 - val_loss: 2.1239 - val_accuracy: 0.7033
# Epoch 12/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.9021 - accuracy: 0.6977 - val_loss: 2.4013 - val_accuracy: 0.6500
# Epoch 13/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.8078 - accuracy: 0.7189 - val_loss: 2.8614 - val_accuracy: 0.6333
# Epoch 14/50
# 10/10 [==============================] - 45s 5s/step - loss: 2.1059 - accuracy: 0.6953 - val_loss: 1.7623 - val_accuracy: 0.7300
# Epoch 15/50
# 10/10 [==============================] - 45s 5s/step - loss: 2.1366 - accuracy: 0.6779 - val_loss: 2.2714 - val_accuracy: 0.6867
# Epoch 16/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.8420 - accuracy: 0.7219 - val_loss: 2.5364 - val_accuracy: 0.6967
# Epoch 17/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.8302 - accuracy: 0.7334 - val_loss: 2.3262 - val_accuracy: 0.7000
# Epoch 18/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.8974 - accuracy: 0.7111 - val_loss: 2.6317 - val_accuracy: 0.6700
# Epoch 19/50
# 10/10 [==============================] - 46s 5s/step - loss: 2.2966 - accuracy: 0.6987 - val_loss: 2.4896 - val_accuracy: 0.6800
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 20/50
# 10/10 [==============================] - 46s 5s/step - loss: 2.0080 - accuracy: 0.7193 - val_loss: 1.7819 - val_accuracy: 0.7367
# Epoch 21/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.9943 - accuracy: 0.7498 - val_loss: 2.4893 - val_accuracy: 0.7000
# Epoch 22/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.8421 - accuracy: 0.7337 - val_loss: 2.4361 - val_accuracy: 0.7067
# Epoch 23/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.7767 - accuracy: 0.7511 - val_loss: 2.1689 - val_accuracy: 0.6867
# Epoch 24/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.6469 - accuracy: 0.7592 - val_loss: 2.2823 - val_accuracy: 0.7200
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 25/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.7972 - accuracy: 0.7558 - val_loss: 2.1876 - val_accuracy: 0.7167
# Epoch 26/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.7127 - accuracy: 0.7665 - val_loss: 2.4073 - val_accuracy: 0.7267
# Epoch 27/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.5482 - accuracy: 0.7655 - val_loss: 1.9821 - val_accuracy: 0.7233
# Epoch 28/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.3767 - accuracy: 0.7610 - val_loss: 2.0451 - val_accuracy: 0.6967
# Epoch 29/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.4967 - accuracy: 0.7643 - val_loss: 1.5503 - val_accuracy: 0.7567
# Epoch 30/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.5143 - accuracy: 0.7720 - val_loss: 1.9683 - val_accuracy: 0.7233
# Epoch 31/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.5264 - accuracy: 0.7659 - val_loss: 2.2867 - val_accuracy: 0.7300
# Epoch 32/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.4692 - accuracy: 0.7791 - val_loss: 2.0288 - val_accuracy: 0.6933
# Epoch 33/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.4758 - accuracy: 0.7590 - val_loss: 2.1162 - val_accuracy: 0.7033
# Epoch 34/50
# 10/10 [==============================] - 45s 5s/step - loss: 2.1588 - accuracy: 0.7016 - val_loss: 2.3966 - val_accuracy: 0.6733
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 35/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.7860 - accuracy: 0.7270 - val_loss: 2.3165 - val_accuracy: 0.6900
# Epoch 36/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.2688 - accuracy: 0.8074 - val_loss: 2.1156 - val_accuracy: 0.7067
# Epoch 37/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.4424 - accuracy: 0.7619 - val_loss: 2.0556 - val_accuracy: 0.7300
# Epoch 38/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.7019 - accuracy: 0.7431 - val_loss: 1.9858 - val_accuracy: 0.7200
# Epoch 39/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.4773 - accuracy: 0.7837 - val_loss: 2.3253 - val_accuracy: 0.6933
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 40/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.3559 - accuracy: 0.7815 - val_loss: 1.9852 - val_accuracy: 0.7233
# Epoch 41/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.3444 - accuracy: 0.7833 - val_loss: 1.8946 - val_accuracy: 0.7367
# Epoch 42/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.2436 - accuracy: 0.7817 - val_loss: 2.0165 - val_accuracy: 0.7300
# Epoch 43/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.4475 - accuracy: 0.7675 - val_loss: 2.0194 - val_accuracy: 0.7100
# Epoch 44/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.4100 - accuracy: 0.7616 - val_loss: 1.9325 - val_accuracy: 0.7400
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 45/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.5495 - accuracy: 0.7608 - val_loss: 1.9281 - val_accuracy: 0.7100
# Epoch 46/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.3597 - accuracy: 0.7713 - val_loss: 1.8180 - val_accuracy: 0.7000
# Epoch 47/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.2818 - accuracy: 0.7747 - val_loss: 1.9430 - val_accuracy: 0.7200
# Epoch 48/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.2695 - accuracy: 0.7854 - val_loss: 1.9382 - val_accuracy: 0.7233
# Epoch 49/50
# 10/10 [==============================] - 44s 5s/step - loss: 1.2052 - accuracy: 0.7752 - val_loss: 1.5672 - val_accuracy: 0.7367
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 50/50
# 10/10 [==============================] - 44s 4s/step - loss: 1.2517 - accuracy: 0.7781 - val_loss: 1.8123 - val_accuracy: 0.7333

# %%
from matplotlib import pyplot
pyplot.plot(history6.history['accuracy'], label='train')
pyplot.plot(history6.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## 4. ResNet50 Model:

# %%
base_model=tf.keras.applications.ResNet50(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(256,256,3),
    pooling=None,
    classes=1000
)

for layer in base_model.layers:
    layer.trainable = False

x = Flatten()(base_model.output)
prediction = Dense(5,activation='softmax')(x)
model4 = Model(inputs=base_model.input,outputs=prediction)

# %%
model4.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history7 = model4.fit(train_generator, steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=valid_generator, validation_steps=STEP_SIZE_VALID,
                              epochs=50,
                              shuffle=True,
                              verbose=1,
                              callbacks=[reduce_lr]
                             )
# Out:
# Epoch 1/50
# 10/10 [==============================] - 50s 5s/step - loss: 19.4375 - accuracy: 0.2295 - val_loss: 12.5876 - val_accuracy: 0.2533
# Epoch 2/50
# 10/10 [==============================] - 48s 5s/step - loss: 9.7708 - accuracy: 0.2521 - val_loss: 10.0044 - val_accuracy: 0.2433
# Epoch 3/50
# 10/10 [==============================] - 47s 5s/step - loss: 5.7103 - accuracy: 0.2722 - val_loss: 2.9477 - val_accuracy: 0.3533
# Epoch 4/50
# 10/10 [==============================] - 47s 5s/step - loss: 2.9216 - accuracy: 0.3174 - val_loss: 2.3680 - val_accuracy: 0.3267
# Epoch 5/50
# 10/10 [==============================] - 46s 5s/step - loss: 2.0488 - accuracy: 0.3191 - val_loss: 1.8283 - val_accuracy: 0.3667
# Epoch 6/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.8380 - accuracy: 0.3601 - val_loss: 1.7529 - val_accuracy: 0.4467
# Epoch 7/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.5947 - accuracy: 0.4070 - val_loss: 1.4968 - val_accuracy: 0.3867
# Epoch 8/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.4934 - accuracy: 0.4162 - val_loss: 1.5847 - val_accuracy: 0.3200
# Epoch 9/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.4063 - accuracy: 0.4121 - val_loss: 1.7082 - val_accuracy: 0.3367
# Epoch 10/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.4667 - accuracy: 0.3878 - val_loss: 1.4126 - val_accuracy: 0.4433
# Epoch 11/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3414 - accuracy: 0.4355 - val_loss: 1.3483 - val_accuracy: 0.4367
# Epoch 12/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.3493 - accuracy: 0.4483 - val_loss: 1.5042 - val_accuracy: 0.3933
# Epoch 13/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.6649 - accuracy: 0.3978 - val_loss: 1.5505 - val_accuracy: 0.3967
# Epoch 14/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.5048 - accuracy: 0.3777 - val_loss: 1.5719 - val_accuracy: 0.4100
# Epoch 15/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.4736 - accuracy: 0.4112 - val_loss: 1.2385 - val_accuracy: 0.5400
# Epoch 16/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.3499 - accuracy: 0.4598 - val_loss: 1.3815 - val_accuracy: 0.4767
# Epoch 17/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3966 - accuracy: 0.4196 - val_loss: 1.3628 - val_accuracy: 0.5033
# Epoch 18/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3794 - accuracy: 0.4539 - val_loss: 1.4801 - val_accuracy: 0.4433
# Epoch 19/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3550 - accuracy: 0.4606 - val_loss: 1.3524 - val_accuracy: 0.5000
# Epoch 20/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3497 - accuracy: 0.4866 - val_loss: 1.4027 - val_accuracy: 0.4067
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 21/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3194 - accuracy: 0.4791 - val_loss: 1.3856 - val_accuracy: 0.4467
# Epoch 22/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3388 - accuracy: 0.4380 - val_loss: 1.2513 - val_accuracy: 0.5200
# Epoch 23/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.3693 - accuracy: 0.4506 - val_loss: 1.3816 - val_accuracy: 0.4633
# Epoch 24/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.3383 - accuracy: 0.4682 - val_loss: 1.4249 - val_accuracy: 0.5200
# Epoch 25/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.3292 - accuracy: 0.4783 - val_loss: 1.4099 - val_accuracy: 0.4833
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 26/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.4259 - accuracy: 0.4330 - val_loss: 1.5163 - val_accuracy: 0.3733
# Epoch 27/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3355 - accuracy: 0.4523 - val_loss: 1.3327 - val_accuracy: 0.4433
# Epoch 28/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.2587 - accuracy: 0.4850 - val_loss: 1.3012 - val_accuracy: 0.4333
# Epoch 29/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.2297 - accuracy: 0.4983 - val_loss: 1.1620 - val_accuracy: 0.5467
# Epoch 30/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.2144 - accuracy: 0.5008 - val_loss: 1.2607 - val_accuracy: 0.5200
# Epoch 31/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.2118 - accuracy: 0.5109 - val_loss: 1.3571 - val_accuracy: 0.4700
# Epoch 32/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.2187 - accuracy: 0.5109 - val_loss: 1.4491 - val_accuracy: 0.4767
# Epoch 33/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3039 - accuracy: 0.4732 - val_loss: 1.3343 - val_accuracy: 0.4800
# Epoch 34/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.3337 - accuracy: 0.4858 - val_loss: 1.2750 - val_accuracy: 0.5367
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 35/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.3176 - accuracy: 0.4883 - val_loss: 1.2749 - val_accuracy: 0.5200
# Epoch 36/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.3146 - accuracy: 0.4724 - val_loss: 1.3508 - val_accuracy: 0.5133
# Epoch 37/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.1739 - accuracy: 0.5268 - val_loss: 1.1341 - val_accuracy: 0.5500
# Epoch 38/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.1581 - accuracy: 0.5444 - val_loss: 1.2735 - val_accuracy: 0.5000
# Epoch 39/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.2095 - accuracy: 0.5117 - val_loss: 1.3327 - val_accuracy: 0.5300
# Epoch 40/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.2206 - accuracy: 0.5168 - val_loss: 1.3016 - val_accuracy: 0.4500
# Epoch 41/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.2324 - accuracy: 0.4791 - val_loss: 1.1545 - val_accuracy: 0.5100
# Epoch 42/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.1911 - accuracy: 0.5176 - val_loss: 1.3445 - val_accuracy: 0.4500
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 43/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.1844 - accuracy: 0.5042 - val_loss: 1.3315 - val_accuracy: 0.5300
# Epoch 44/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.2031 - accuracy: 0.5025 - val_loss: 1.2355 - val_accuracy: 0.4633
# Epoch 45/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.1522 - accuracy: 0.5251 - val_loss: 1.1550 - val_accuracy: 0.5700
# Epoch 46/50
# 10/10 [==============================] - 45s 5s/step - loss: 1.1265 - accuracy: 0.5494 - val_loss: 1.2118 - val_accuracy: 0.5300
# Epoch 47/50
# 10/10 [==============================] - 46s 5s/step - loss: 1.1531 - accuracy: 0.5385 - val_loss: 1.2441 - val_accuracy: 0.5400
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 48/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.1645 - accuracy: 0.5343 - val_loss: 1.2249 - val_accuracy: 0.5067
# Epoch 49/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.1595 - accuracy: 0.5276 - val_loss: 1.1698 - val_accuracy: 0.5667
# Epoch 50/50
# 10/10 [==============================] - 47s 5s/step - loss: 1.1802 - accuracy: 0.5193 - val_loss: 1.1606 - val_accuracy: 0.5333

# %%
pyplot.plot(history7.history['accuracy'], label='train')
pyplot.plot(history7.history['val_accuracy'], label='test')
pyplot.legend()
pyplot.show()
